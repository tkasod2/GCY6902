# %%
# !pip freeze > requirements.txt

# %%
import requests
import json
url = "http://localhost:11434/api/generate"

payload = {
    "model": "qwen2.5:3b",
    "prompt": "비트코인 자동매매에서 LLM의 역할을 3문장으로 설명해줘.",
    "stream": False
}

response = requests.post(url, json=payload)

print(response.json()["response"])
# Out:
# LLM은 비트코인 가격 추세 분석과 거래 전략 제안에 활용될 수 있으며, 시장 데이터를 분석하여 매수/매도 결정에 기여할 것입니다.

# %%
import requests
import json

model_output = {
    "prob_up": 0.71,
    "pred_return": 0.008,
    "signal": "buy"
}

prompt = f"""
다음은 비트코인 예측모델 결과다:

{json.dumps(model_output, indent=2)}

이 결과를 기반으로
1) 매수 판단
2) 근거
3) 리스크
를 한국어로 설명해줘.
"""

payload = {
    "model": "qwen2.5:3b",
    "prompt": prompt,
    "stream": False,
    "options": {
        "num_predict": 500,
        "temperature": 0.7
    }
}

res = requests.post("http://localhost:11434/api/generate", json=payload)

print(res.json()["response"])
# Out:
# 1) 매수 판단:
# 비트코인의 예측 모델은 현재 상승 전망을 나타내며, 비트코인이 앞으로 상승할 가능성이 높다고 보여집니다. 이 결과는 비트코인 가격이 오를 것으로 예상되기 때문에, 매수 판단에 적합합니다.
#
# 2) 근거:
# 비트코인의 예측 모델에서 가장 중요한 요소는 'prob_up'(상승 확률)입니다. 이번에는 0.71로 상승 가능성이 높음을 나타냅니다. 또한, 'pred_return'가 0.008이 되어, 비트코인이 오를 것이라는 전망을 지원합니다. 마지막으로, 예측 모델의 'signal'(시그널)은 'buy'(매수)로 나와 이를 바탕으로 매수가 권장되고 있습니다.
#
# 3) 리스크:
# 비트코인은 급변하는 시장에서 손실이 발생할 수 있는 투자입니다. 따라서, 이 예측 모델을 기반으로 매수를 결정하더라도, 주의 깊게 관리해야 합니다. 비트코인 가격 변동성이 크기 때문에, 적절한 롱 레버리지와 위험 관리 전략이 필요합니다. 또한 시장 조건이나 개인 투자 목표에 따라 매수 결정을 재고할 필요가 있습니다.
