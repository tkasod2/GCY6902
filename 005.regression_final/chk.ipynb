# %%
import pandas as pd
import os

# %%
dir__ = r'G:\내 드라이브\GCY6902_01_TFT\005.regression_final/outputs/dl/'
lst_folder = [x for x in os.listdir(dir__) if x.startswith('260515')]
file_nm_ = 'Close_final_report_260515.xlsx'

# %%
folder = lst_folder[0]
pd.read_excel(folder+'/'+file_nm_, sheet_name='6.')
