# %%
# python 3.12.12
# pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# pip install seaborn
# pip install scikit-learn

from run import *

# %%
df = pd.read_parquet('./data/df_260315.parquet',engine='fastparquet')
print(df.shape)
print(df.head())
# Out:
# (139924, 12)
#       Open     High      Low    Close      Volume              Close time  \
# 0  0.04968  0.05140  0.04949  0.05094  53823.8559 2024-05-01 23:59:59.999
# 1  0.05094  0.05161  0.05037  0.05055  31896.3678 2024-05-02 23:59:59.999
# 2  0.05055  0.05078  0.04925  0.04934  31633.2277 2024-05-03 23:59:59.999
# 3  0.04934  0.04970  0.04875  0.04879  18054.0630 2024-05-04 23:59:59.999
# 4  0.04879  0.04965  0.04858  0.04899  16878.6574 2024-05-05 23:59:59.999
#
#   Quote asset volume  Number of trades Taker buy base asset volume  \
# 0      2715.82238206            177665              27896.64200000
# 1      1621.28357957            107466              15688.28470000
# 2      1579.95833005            113175              14428.12320000
# 3       888.11955777             83140               9011.75720000
# 4       828.16583151             64357               8558.99060000
#
#   Taker buy quote asset volume Ignore  Symbol
# 0                1407.21806973      0  ETHBTC
# 1                 797.66103753      0  ETHBTC
# 2                 721.65691725      0  ETHBTC
# 3                 443.37515408      0  ETHBTC
# 4                 420.20757916      0  ETHBTC

# %%
outdir = "./output/" + datetime.now().strftime('%y%m%d%H%M%S') + "/"
os.mkdir(outdir)

fit_and_out(df=df, target='Close', outdir=outdir)
# Out:
# Train set - x_past: (48257, 30, 9), x_static: (48257, 1)
# Valid set - x_past: (6727, 30, 9), x_static: (6727, 1)
# Test set - x_past: (64032, 30, 9), x_static: (64032, 1)
# =======1. TFT 모델 학습중=======
# [epoch 001] val_loss=0.091989 | ts_loss =0.834860 lr=1.00e-03
#   -> saved best to ./output/260316234812/Close_tft_test_260312.pt
# [epoch 002] val_loss=0.067203 | ts_loss =0.335445 lr=1.00e-03
#   -> saved best to ./output/260316234812/Close_tft_test_260312.pt
# [epoch 003] val_loss=0.083279 | ts_loss =0.284238 lr=1.00e-03
# [epoch 004] val_loss=0.059782 | ts_loss =0.415107 lr=1.00e-03
#   -> saved best to ./output/260316234812/Close_tft_test_260312.pt
# [epoch 005] val_loss=0.071015 | ts_loss =0.356124 lr=1.00e-03
# [epoch 006] val_loss=0.069208 | ts_loss =0.358120 lr=1.00e-03
# [epoch 007] val_loss=0.063334 | ts_loss =0.391428 lr=1.00e-03
# [epoch 008] val_loss=0.977886 | ts_loss =2.956012 lr=1.00e-03
# [epoch 009] val_loss=0.049024 | ts_loss =0.473146 lr=1.00e-03
#   -> saved best to ./output/260316234812/Close_tft_test_260312.pt
# [epoch 010] val_loss=0.057089 | ts_loss =0.389004 lr=1.00e-03
# [epoch 011] val_loss=0.051792 | ts_loss =0.429215 lr=1.00e-03
# [epoch 012] val_loss=0.054125 | ts_loss =0.407778 lr=1.00e-03
# [epoch 013] val_loss=0.048819 | ts_loss =0.473479 lr=1.00e-03
#   -> saved best to ./output/260316234812/Close_tft_test_260312.pt
# [epoch 014] val_loss=0.069683 | ts_loss =0.326045 lr=1.00e-03
# [epoch 015] val_loss=0.067874 | ts_loss =0.333252 lr=1.00e-03
# [epoch 016] val_loss=0.053272 | ts_loss =0.415186 lr=1.00e-03
# [epoch 017] val_loss=0.066955 | ts_loss =0.337126 lr=1.00e-03
# [epoch 018] val_loss=0.049611 | ts_loss =0.457039 lr=1.00e-03
#   -> early stopping
# =======2. LSTM 모델 학습중=======
# [LSTM Epoch 001] val_loss=0.048374 test_loss=0.486114
#   -> saved best LSTM to ./output/260316234812/Close_lstm_test_260312.pt
# [LSTM Epoch 002] val_loss=0.053167 test_loss=0.415821
# [LSTM Epoch 003] val_loss=0.064975 test_loss=0.344793
# [LSTM Epoch 004] val_loss=0.053796 test_loss=0.410074
# [LSTM Epoch 005] val_loss=0.058713 test_loss=0.377186
# [LSTM Epoch 006] val_loss=0.050679 test_loss=0.440653
# [LSTM Epoch 007] val_loss=0.048673 test_loss=0.475057
# [LSTM Epoch 008] val_loss=0.065446 test_loss=0.342943
# [LSTM Epoch 009] val_loss=0.051966 test_loss=0.425999
# [LSTM Epoch 010] val_loss=0.056489 test_loss=0.390149
# [LSTM Epoch 011] val_loss=0.053060 test_loss=0.418962
#   -> early stopping
# ====================output building 중====================
# c:\Users\rbs\Dropbox\101.대학원생활\1학년2학기\04_노알버트_첨단컴퓨팅세미나_목1\GCY6902\run.py:180: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=imp_df.head(10), x='Importance', y='Feature', ax=axes[1], palette='viridis')
# Chart saved at: ./output/260316234812/Close_comparison_summary.png

# %%
# past_outdir = "./output/260316_test/" 
# load_and_output(
#     df=df,
#     tft_path=past_outdir + "Close_tft_test_260312.pt",
#     lstm_path=past_outdir + "Close_lstm_test_260312.pt",
#     target='Close',
#     outdir=past_outdir,
#     seq_length=30 # 현재 30일짜리임.
# )
# Out:
# ====================output building 중====================
# c:\Users\rbs\Dropbox\101.대학원생활\1학년2학기\04_노알버트_첨단컴퓨팅세미나_목1\GCY6902\run.py:272: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=imp_df.head(10), x='Importance', y='Feature', ax=axes[1], palette='viridis')
# Chart saved at: ./output/260316_test/Close_comparison_summary.png
